# %%
import requests 
import matplotlib.animation as animation
from bs4 import BeautifulSoup 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt  
import time 
from itertools import count
import random

# %%
headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'}

# %%
ticker = 'PLTR'
url = (f'https://ca.finance.yahoo.com/quote/{ticker}?.tsrc=fin-srch' )
response = requests.get(url, headers= headers) 
html_content = response.text

# %%
active_price_list = []
def Stock_price(): 
    response = requests.get(url, headers= headers)  
    soup = BeautifulSoup(response.text, 'lxml') 
    active_price = soup.find('div', {"class" : 'My(6px) Pos(r) smartphone_Mt(6px) W(100%)' }).find('fin-streamer').text  
    active_price_list.append(active_price)
    return active_price   

try:
    while True:
    
        print(Stock_price()) 
except KeyboardInterrupt:
    print("Stopped.")
# Out:
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16
# 26.16

# %%
def Stock_price_change():
    response = requests.get(url, headers= headers)  
    soup = BeautifulSoup(response.text, 'lxml') 
    active_price = soup.find('div', {"class" : 'My(6px) Pos(r) smartphone_Mt(6px) W(100%)' }).find('fin-streamer').text  
    return active_price

# %%
response = requests.get(url, headers= headers)
soup = BeautifulSoup(response.text, 'lxml') 
hist_price = soup.find('div',{"class": 'Pos(r) Bgc($bg-content) Bgc($lv2BgColor)! Miw(1007px) Maw(1260px) tablet_Miw(600px)--noRightRail Bxz(bb) Bdstartc(t) Bdstartw(20px) Bdendc(t) Bdends(s) Bdendw(20px) Bdstarts(s) Mx(a)'})

# %%
print(hist_price.find('table').text)
# Out:
# Previous Close25.08Open25.30Bid23.97 x 3200Ask24.01 x 1200Day's Range24.54 - 25.6952 Week Range7.19 - 25.69Volume64,794,407Avg. Volume69,282,167

# %%
index = count() 
prices = []

plt.ion()  # Enable interactive mode

def Stock_price(): 
    response = requests.get(url, headers= headers)  
    soup = BeautifulSoup(response.text, 'lxml') 
    active_price = soup.find('div', {"class" : 'My(6px) Pos(r) smartphone_Mt(6px) W(100%)' }).find('fin-streamer').text  
    
    return active_price  

def live_plot(data):
    plt.clf()  # Clear the current figure
    plt.plot(data)
    plt.title("Real-Time Stock Price")
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.draw()
    plt.pause(0.1)  # Pause to allow the plot to be redrawn

try:
    while True:
        # Simulate price update; replace with actual data fetching
        price = active_price
        prices.append(price)
        
        live_plot(prices)
        
        # Simulate real-time delay; adjust as needed
        time.sleep(2)
except KeyboardInterrupt:
    print("Stopped.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 index = count()
#       2 prices = []
#       4 plt.ion()  # Enable interactive mode
#
# NameError: name 'count' is not defined

# %%
def Stock_price(): 
    response = requests.get(url, headers= headers)  
    soup = BeautifulSoup(response.text, 'lxml') 
    active_price = soup.find('div', {"class" : 'My(6px) Pos(r) smartphone_Mt(6px) W(100%)' }).find('fin-streamer').text  
    
    return float(active_price.replace(',', ''))  



fig, ax = plt.subplots()
xdata, ydata = [], []
ln, = plt.plot([], [], 'r-', animated=True)

def init():
    ax.set_xlim(0, 20)  # Initial x-axis range
    ax.set_ylim(0, 40)  # Adjust y-axis range based on expected stock price variation
    return ln,

def update(frame):
    price = Stock_price()
    xdata.append(frame)
    ydata.append(price)
    ln.set_data(xdata, ydata)
    return ln,

ani = animation.FuncAnimation(fig, update, frames=count(1), init_func=init, blit=True, interval=1000, cache_frame_data=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       4     active_price = soup.find('div', {"class" : 'My(6px) Pos(r) smartphone_Mt(6px) W(100%)' }).find('fin-streamer').text
#       6     return float(active_price.replace(',', ''))
# ---> 10 fig, ax = plt.subplots()
#      11 xdata, ydata = [], []
#      12 ln, = plt.plot([], [], 'r-', animated=True)
#
# NameError: name 'plt' is not defined
